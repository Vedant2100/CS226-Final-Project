# %% [markdown]
# INSTALL DEPENDENCIES

# %%
import os
from google.colab import userdata

# List of secrets your notebook needs based on your screenshot
required_secrets = [
    "AWS_ACCESS_KEY_ID",
    "AWS_SECRET_ACCESS_KEY",
    "DB_HOST",
    "DB_PASSWORD",
    "S3_BUCKET_NAME"
]

missing_secrets = []

for secret in required_secrets:
    try:
        val = userdata.get(secret)
        os.environ[secret] = val # Set as environment variable for Boto3/DB drivers
    except:
        missing_secrets.append(secret)

if missing_secrets:
    print("⚠️  MISSING SECRETS DETECTED:")
    print(f"Please click the 🔑 icon on the left and add: {', '.join(missing_secrets)}")
    print("Ensure 'Notebook access' is toggled ON for each.")
else:
    print("✅ All secrets loaded successfully.")
# Out:
# ✅ All secrets loaded successfully.

# %%
# !apt-get install -y gdal-bin libgdal-dev 2>/dev/null | tail -3
# !pip install -q rasterio==1.3.10 shapely psycopg2-binary boto3 numpy tqdm
# !pip install boto3 botocore
# Out:
# Setting up python3-gdal (3.8.4+dfsg-1~jammy0) ...
# Setting up gdal-bin (3.8.4+dfsg-1~jammy0) ...
# Processing triggers for man-db (2.10.2-1) ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 103.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 84.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.13.0 requires rasterio>=1.4, but you have rasterio 1.3.10 which is incompatible.
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (1.42.68)
# Requirement already satisfied: botocore in /usr/local/lib/python3.12/dist-packages (1.42.68)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.17.0)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# import os
# DRIVE_SOURCE_DIR = '/content/drive/MyDrive/BigDataProject'

# %% [markdown]
# USE TO CONNECT TO AWS

# %%
from google.colab import userdata
AWS_ACCESS_KEY_ID     = userdata.get('AWS_ACCESS_KEY_ID')
AWS_SECRET_ACCESS_KEY = userdata.get('AWS_SECRET_ACCESS_KEY')
AWS_REGION            = 'us-west-1'
S3_BUCKET_NAME        = userdata.get('S3_BUCKET_NAME')
print(f"AWS credentials loaded. Region: {AWS_REGION} | Bucket: {S3_BUCKET_NAME}")

DB_CONFIG = {
    'host':     userdata.get('DB_HOST'),
    'port':     5432,
    'database': 'postgres',
    'user':     'postgres',
    'password': userdata.get('DB_PASSWORD'),
    'connect_timeout': 10
}
S3_RAW_PREFIX = 'raw/'

LOCAL_WORK_DIR = '/tmp/vegetation_pipeline'
os.makedirs(LOCAL_WORK_DIR, exist_ok=True)
# Out:
# AWS credentials loaded. Region: us-west-1 | Bucket: vegetation-anomaly-cogs

# %%
from pyproj import Transformer
import re
import datetime
import numpy as np
import rasterio
from rasterio.transform import array_bounds
from rasterio.warp import transform_bounds
from rasterio.crs import CRS
from shapely.geometry import box as shapely_box

def parse_hls_filename(filepath):
    filename    = os.path.basename(filepath)
    name_no_ext = filename.replace('.tif', '').replace('.TIF', '')

    # HLS pattern: HLS.{S30|L30}.{tile}.{YYYY}{DOY}T{HHMMSS}.{version}[.{band}]
    hls_pattern = r'^HLS\.([SL]30)\.([A-Z0-9]+)\.(\d{4})(\d{3})T(\d{6})\.([\d\.v]+)(?:\.([A-Z0-9_]+))?$'
    match = re.match(hls_pattern, name_no_ext)

    if match:
        product  = match.group(1)
        tile     = match.group(2)
        year     = int(match.group(3))
        doy      = int(match.group(4))
        acq_date = datetime.date(year, 1, 1) + datetime.timedelta(days=doy - 1)
        tile_id  = f"{product}_{tile}_{year}{doy:03d}"

        return {
            'tile_id':          tile_id,
            'acquisition_date': acq_date,
            'product':          product,
            'tile':             tile,
            'band':             match.group(7) or 'MULTI',
            'version':          match.group(6),
            'year':             year,
            'doy':              doy,
            'filename':         filename,
        }

    # veg_YYYY-MM-DD pattern
    print(f"  [WARN] Non-HLS filename: {filename}. Attempting 'veg_YYYY-MM-DD' format.")
    veg_pattern = r'^veg_(\d{4})-(\d{2})-(\d{2})(?:\.cog)?$'
    veg_match   = re.match(veg_pattern, name_no_ext)

    if veg_match:
        year     = int(veg_match.group(1))
        month    = int(veg_match.group(2))
        day      = int(veg_match.group(3))
        acq_date = datetime.date(year, month, day)

        return {
            'tile_id':          name_no_ext,
            'acquisition_date': acq_date,
            'product':          'CUSTOM_VEG',
            'tile':             name_no_ext,
            'band':             'MULTI',
            'version':          'parsed',
            'year':             year,
            'doy':              acq_date.timetuple().tm_yday,
            'filename':         filename,
        }

    # Final fallback
    print(f"  [WARN] Unrecognized filename: {filename}. Using generic fallback.")
    year_match = re.search(r'(20[12][0-9])', filename)
    year = int(year_match.group(1)) if year_match else datetime.datetime.now().year

    return {
        'tile_id':          name_no_ext,
        'acquisition_date': datetime.date(datetime.datetime.now().year, 1, 1),
        'product':          'UNKNOWN',
        'tile':             name_no_ext,
        'band':             'MULTI',
        'version':          'unknown',
        'year':             year,
        'doy':              1,
        'filename':         filename,
    }


def extract_raster_metadata(filepath):
    metadata = {}

    with rasterio.open(filepath) as src:
        metadata['crs']          = str(src.crs)
        metadata['width_px']     = src.width
        metadata['height_px']    = src.height
        metadata['band_count']   = src.count
        metadata['resolution_m'] = abs(src.res[0])

        src_bounds = src.bounds

        if src.crs and str(src.crs) != 'EPSG:4326':
            try:
                transformer = Transformer.from_crs(
                    src.crs, "EPSG:4326", always_xy=True
                )
                west,  south = transformer.transform(src_bounds.left,  src_bounds.bottom)
                east,  north = transformer.transform(src_bounds.right, src_bounds.top)

                # Sanity check — WGS84 longitude must be between -180 and 180
                if not (-180 <= west <= 180 and -180 <= east <= 180):
                    raise ValueError(f"Invalid WGS84 lon: west={west}, east={east}")

                metadata['bbox_wgs84'] = {
                    'west': west, 'south': south,
                    'east': east, 'north': north
                }
                print(f"  BBox WGS84: W={west:.4f} S={south:.4f} E={east:.4f} N={north:.4f}")

            except Exception as e:
                print(f"  [WARN] CRS reprojection failed: {e}. Using native bounds.")
                metadata['bbox_wgs84'] = {
                    'west':  src_bounds.left,  'south': src_bounds.bottom,
                    'east':  src_bounds.right, 'north': src_bounds.top,
                }
        else:
            # Already WGS84
            metadata['bbox_wgs84'] = {
                'west':  src_bounds.left,  'south': src_bounds.bottom,
                'east':  src_bounds.right, 'north': src_bounds.top,
            }

        metadata['is_tiled']      = src.is_tiled
        metadata['compression']   = str(src.compression) if src.compression else 'None'
        metadata['has_overviews'] = len(src.overviews(1)) > 0

    return metadata
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import subprocess
import time
import os
import rasterio
from rasterio.enums import Resampling

def validate_cog(filepath):
    result = {
        'is_valid': False,
        'is_tiled': False,
        'has_overviews': False,
        'compression': None,
        'issues': []
    }

    try:
        with rasterio.open(filepath) as src:
            result['is_tiled']     = src.is_tiled
            result['compression']  = str(src.compression) if src.compression else 'None'
            result['overviews']    = src.overviews(1)
            result['has_overviews'] = len(src.overviews(1)) > 0
            result['width']        = src.width
            result['height']       = src.height

            # Check for COG ghost metadata
            tags = src.tags()
            result['has_cog_marker'] = 'OVR_RESAMPLING_ALG' in tags or src.is_tiled

            if not result['is_tiled']:
                result['issues'].append("Not internally tiled (required for efficient S3 reads)")
            if not result['has_overviews']:
                result['issues'].append("No overviews (partial zoom reads will be slow)")
            if result['compression'] in ['None', None]:
                result['issues'].append("No compression (wastes S3 storage and transfer costs)")

        result['is_valid'] = len(result['issues']) == 0
    except Exception as e:
        result['issues'].append(f"Cannot open file: {e}")

    return result

def convert_to_cog(input_path, output_path, config):
    if not os.path.exists(input_path):
        return {'success': False, 'error': f"Input file not found: {input_path}"}

    compress  = config.get('cog_compress', 'LZW')
    blocksize = config.get('cog_blocksize', 512)

    cmd = [
        'gdal_translate', '-of', 'COG',
        '-co', f'COMPRESS={compress}',
        '-co', f'BLOCKSIZE={blocksize}',
        '-co', 'OVERVIEWS=AUTO',
        '-co', 'RESAMPLING=AVERAGE',
        '-co', 'BIGTIFF=IF_SAFER',
        '--config', 'GDAL_TIFF_OVR_BLOCKSIZE', str(blocksize),
        input_path, output_path
    ]

    print(f"  Converting to COG: {os.path.basename(input_path)}")
    start_time = time.time()

    try:
        proc = subprocess.run(cmd, capture_output=True, text=True, timeout=300)
        duration = round(time.time() - start_time, 2)

        if proc.returncode != 0:
            print(f"  [ERROR] {proc.stderr[:200]}")
            return {'success': False, 'error': proc.stderr}

        input_mb  = os.path.getsize(input_path)  / 1e6
        output_mb = os.path.getsize(output_path) / 1e6
        print(f"  Done in {duration}s | {input_mb:.1f} MB -> {output_mb:.1f} MB "
              f"({input_mb/output_mb:.1f}x compression)")

        return {
            'success': True,
            'output_path': output_path,
            'duration_sec': duration,
            'input_size_mb': round(input_mb, 2),
            'file_size_mb': round(output_mb, 2),
        }

    except subprocess.TimeoutExpired:
        return {'success': False, 'error': 'Conversion timed out after 5 minutes'}
    except Exception as e:
        return {'success': False, 'error': str(e)}
def benchmark_cog_vs_original(original_path, cog_path, n_trials=3):
    results = {}

    for label, path in [('Original', original_path), ('COG', cog_path)]:
        if not os.path.exists(path):
            continue
        times = []
        with rasterio.open(path) as src:
            w, h = src.width, src.height
            # Read a 500x500 window from center
            window = rasterio.windows.Window(
                col_off=w // 4, row_off=h // 4,
                width=min(500, w // 2), height=min(500, h // 2)
            )
            for _ in range(n_trials):
                t0 = time.time()
                _ = src.read(1, window=window)
                times.append(time.time() - t0)

        results[label] = {
            'mean_ms': round(np.mean(times) * 1000, 1),
            'min_ms':  round(np.min(times) * 1000, 1),
        }

    if 'Original' in results and 'COG' in results:
        speedup = results['Original']['mean_ms'] / results['COG']['mean_ms']
        print(f"  Benchmark Results ({n_trials} trials):")
        print(f"    Original: {results['Original']['mean_ms']:.1f}ms avg")
        print(f"    COG:      {results['COG']['mean_ms']:.1f}ms avg")
        print(f"    Speedup:  {speedup:.1f}x faster with COG")
        print(f"  (On S3, this speedup is typically 10-50x for partial reads)")

    return results
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import boto3
from botocore.exceptions import ClientError, NoCredentialsError


def get_s3_client(config):
    try:
        s3 = boto3.client(
            's3',
            aws_access_key_id     = config['aws_access_key_id'],
            aws_secret_access_key = config['aws_secret_access_key'],
            region_name           = config['aws_region']
        )
        # Quick connectivity test: list first page of bucket objects
        s3.list_objects_v2(Bucket=config['s3_bucket'], MaxKeys=1)
        print(f"  S3 connected: s3://{config['s3_bucket']} (region: {config['aws_region']})")
        return s3
    except NoCredentialsError:
        print("  [ERROR] Invalid AWS credentials. Check your Colab Secrets.")
        return None
    except ClientError as e:
        if e.response['Error']['Code'] == 'NoSuchBucket':
            print(f"  [ERROR] Bucket '{config['s3_bucket']}' does not exist.")
        else:
            print(f"  [ERROR] S3 connection failed: {e}")
        return None

def upload_cog_to_s3(local_path, config, s3_client, tile_metadata):
    year = tile_metadata.get('year', 2020)
    tile_id = tile_metadata.get('tile_id', 'unknown')
    filename = os.path.basename(local_path)

    # Build S3 key with year-based prefix
    s3_key = f"{config['s3_cog_prefix']}{year}/{tile_id}.cog.tif"
    s3_url = f"s3://{config['s3_bucket']}/{s3_key}"

    # Check if already uploaded (skip if exists)
    if config.get('skip_existing'):
        try:
            s3_client.head_object(Bucket=config['s3_bucket'], Key=s3_key)
            print(f"  [SKIP] Already in S3: {s3_url}")
            return s3_url
        except ClientError as e:
            if e.response['Error']['Code'] != '404':
                pass  # File doesn't exist, proceed with upload

    file_size_mb = os.path.getsize(local_path) / 1e6
    print(f"  Uploading {file_size_mb:.1f} MB -> {s3_url}")

    try:
        # Use upload_file for automatic multipart uploads (>8 MB)
        s3_client.upload_file(
            local_path,
            config['s3_bucket'],
            s3_key,
            ExtraArgs={
                'ContentType': 'image/tiff',
                'StorageClass': 'STANDARD',
                'Metadata': {
                    'tile-id':          tile_id,
                    'acquisition-date': str(tile_metadata.get('acquisition_date', '')),
                    'product':          tile_metadata.get('product', 'HLS'),
                }
            }
        )
        print(f"  Upload complete: {s3_url}")
        return s3_url

    except Exception as e:
        print(f"  [ERROR] S3 upload failed: {e}")
        return None

def download_from_s3(s3_key, local_dest, config, s3_client):
    local_path = os.path.join(local_dest, os.path.basename(s3_key))
    if os.path.exists(local_path):
        print(f"  [CACHE] Already downloaded: {os.path.basename(s3_key)}")
        return local_path

    try:
        obj = s3_client.head_object(Bucket=config['s3_bucket'], Key=s3_key)
        size_mb = obj['ContentLength'] / 1e6
        print(f"  Downloading {size_mb:.1f} MB from s3://{config['s3_bucket']}/{s3_key}")

        s3_client.download_file(config['s3_bucket'], s3_key, local_path)
        print(f"  Downloaded -> {local_path}")
        return local_path
    except Exception as e:
        print(f"  [ERROR] S3 download failed: {e}")
        return None

def list_s3_raw_files(config, s3_client):
    paginator = s3_client.get_paginator('list_objects_v2')
    pages = paginator.paginate(
        Bucket=config['s3_bucket'],
        Prefix=config['s3_raw_prefix']
    )
    keys = []
    for page in pages:
        for obj in page.get('Contents', []):
            key = obj['Key']
            if key.endswith('.tif') or key.endswith('.TIF'):
                keys.append(key)
    print(f"  Found {len(keys)} raw TIF files in s3://{config['s3_bucket']}/{config['s3_raw_prefix']}")
    return keys
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import psycopg2
from psycopg2 import sql
import datetime

def get_db_connection(config):
    db_config = config['db_config']
    try:
        conn = psycopg2.connect(
            host=db_config['host'],
            port=db_config['port'],
            database=db_config['database'],
            user=db_config['user'],
            password=db_config['password'],
            connect_timeout=db_config.get('connect_timeout', 10)
        )
        conn.autocommit = False   # Use explicit transactions

        # Test PostGIS availability
        cur = conn.cursor()
        cur.execute("CREATE EXTENSION IF NOT EXISTS postgis;")
        cur.execute("SELECT PostGIS_Version();")
        postgis_ver = cur.fetchone()[0]
        cur.execute("SELECT version();")
        pg_ver = cur.fetchone()[0].split(' ')[1]

        print(f"  Database connected successfully!")
        print(f"  PostgreSQL version: {pg_ver}")
        print(f"  PostGIS version: {postgis_ver.split(' ')[0]}")
        cur.close()
        return conn

    except psycopg2.OperationalError as e:
        print(f"  [ERROR] Cannot connect to database: {e}")
        print(f"  Check: 1) RDS endpoint correct? 2) Security group allows port 5432?")
        print(f"         3) RDS instance is 'Available' in AWS console?")
        return None

def setup_database(conn):
    cur = conn.cursor()

    # Step 1: Enable PostGIS extensions
    print("  Setting up PostGIS extensions...")
    cur.execute("CREATE EXTENSION IF NOT EXISTS postgis;")
    cur.execute("CREATE EXTENSION IF NOT EXISTS postgis_raster;")
    conn.commit()

    # Step 2: Create main metadata table
    # This is the "Spatiotemporal Data Cube Index" from Section 4.4:
    #   - Space:  geom (GEOMETRY Polygon in WGS84)
    #   - Time:   acquisition_date (DATE)
    #   - Link:   file_url (S3 URL or local path to COG)
    print("  Creating vegetation_metadata table...")
    cur.execute("""
        CREATE TABLE IF NOT EXISTS vegetation_metadata (
            id              SERIAL PRIMARY KEY,
            tile_id         TEXT NOT NULL,
            acquisition_date DATE NOT NULL,
            cloud_cover     FLOAT,
            ndvi_mean       FLOAT,
            ndvi_std        FLOAT,
            ndmi_mean       FLOAT,
            crs             TEXT,
            width_px        INTEGER,
            height_px       INTEGER,
            resolution_m    FLOAT,
            band_count      INTEGER,
            compression     TEXT,
            has_overviews   BOOLEAN,
            source          TEXT DEFAULT 'HLS',
            file_url        TEXT,           -- S3 URL or Drive path
            geom            GEOMETRY(Polygon, 4326),  -- WGS84 bounding box polygon
            inserted_at     TIMESTAMP DEFAULT NOW(),
            dataset TEXT DEFAULT 'unknown',
            UNIQUE(tile_id, dataset)                -- Prevent duplicate scene insertions
        );
    """)
    conn.commit()

    # Step 3: Create GIST spatial index
    # This enables fast ST_Intersects queries (the core of the spatiotemporal filter)
    # Equivalent to the "CREATE INDEX ... USING GIST" in Section 4.3 of project outline
    print("  Creating GIST spatial index (idx_vegetation_geom)...")
    cur.execute("""
        CREATE INDEX IF NOT EXISTS idx_vegetation_geom
            ON vegetation_metadata
            USING GIST (geom);
    """)

    # Step 4: Create temporal B-tree index
    # Enables fast date range queries: WHERE acquisition_date BETWEEN '2020-01' AND '2020-12'
    print("  Creating temporal index (idx_vegetation_date)...")
    cur.execute("""
        CREATE INDEX IF NOT EXISTS idx_vegetation_date
            ON vegetation_metadata (acquisition_date);
    """)

    # Step 5: Create composite index for tile+date lookups
    cur.execute("""
        CREATE INDEX IF NOT EXISTS idx_vegetation_tile_date
            ON vegetation_metadata (tile_id, acquisition_date);
    """)

    cur.execute("""
    CREATE INDEX IF NOT EXISTS idx_vegetation_dataset
        ON vegetation_metadata (dataset, acquisition_date);
    """)

    conn.commit()
    print("  Database schema initialized!")

    # Verify setup
    cur.execute("""
        SELECT indexname, indexdef
        FROM pg_indexes
        WHERE tablename = 'vegetation_metadata'
        ORDER BY indexname;
    """)
    indexes = cur.fetchall()
    print(f"  Indexes created: {len(indexes)}")
    for name, defn in indexes:
        print(f"    - {name}")

    cur.close()
    return True

def insert_scene_metadata(conn, tile_meta, raster_meta, file_url, config):
    cur = conn.cursor()

    bbox = raster_meta.get('bbox_wgs84', {})
    west  = bbox.get('west',  0.0)
    south = bbox.get('south', 0.0)
    east  = bbox.get('east',  0.0)
    north = bbox.get('north', 0.0)

    try:
        cur.execute("""
            INSERT INTO vegetation_metadata (
                tile_id, acquisition_date, cloud_cover,
                ndvi_mean, ndvi_std, ndmi_mean,
                crs, width_px, height_px, resolution_m,
                band_count, compression, has_overviews,
                source, file_url,dataset,
                geom
            ) VALUES (
                # %s, %s, %s,
                # %s, %s, %s,
                # %s, %s, %s, %s,
                # %s, %s, %s,
                # %s, %s,
                ST_MakeEnvelope(%s, %s, %s, %s, 4326)
            )
            ON CONFLICT (tile_id, dataset) DO UPDATE SET
                acquisition_date = EXCLUDED.acquisition_date,
                file_url        = EXCLUDED.file_url,
                source          = EXCLUDED.source,
                crs             = EXCLUDED.crs,
                width_px        = EXCLUDED.width_px,
                height_px       = EXCLUDED.height_px,
                resolution_m    = EXCLUDED.resolution_m,
                band_count      = EXCLUDED.band_count,
                compression     = EXCLUDED.compression,
                ndvi_mean       = EXCLUDED.ndvi_mean,
                ndvi_std        = EXCLUDED.ndvi_std,
                ndmi_mean       = EXCLUDED.ndmi_mean,
                has_overviews   = EXCLUDED.has_overviews,
                geom            = EXCLUDED.geom,
                inserted_at     = NOW();
        """, (
            tile_meta.get('tile_id'),
            tile_meta.get('acquisition_date'),
            None,                                   # cloud_cover (not yet computed)
            raster_meta.get('ndvi_mean'),
            raster_meta.get('ndvi_std'),
            raster_meta.get('ndmi_mean'),
            raster_meta.get('crs'),
            raster_meta.get('width_px'),
            raster_meta.get('height_px'),
            raster_meta.get('resolution_m'),
            raster_meta.get('band_count'),
            raster_meta.get('compression'),
            raster_meta.get('has_overviews'),
            tile_meta.get('product', 'HLS'),
            file_url,
            config.get('dataset', 'unknown'),
            west, south, east, north
        ))
        conn.commit()
        cur.close()
        return True

    except psycopg2.errors.UniqueViolation:
        conn.rollback()
        print(f"  [SKIP] Duplicate: {tile_meta.get('tile_id')} already in DB")
        cur.close()
        return False
    except Exception as e:
        conn.rollback()
        print(f"  [ERROR] Insert failed: {e}")
        cur.close()
        return False
def run_spatiotemporal_query(conn, west, south, east, north,
                              start_date, end_date):
    cur = conn.cursor()
    cur.execute("""
        SELECT
            tile_id,
            acquisition_date,
            file_url,
            ndvi_mean,
            resolution_m,
            ST_AsText(geom) AS bbox_wkt
        FROM vegetation_metadata
        WHERE
            ST_Intersects(
                geom,
                ST_MakeEnvelope(%s, %s, %s, %s, 4326)
            )
            AND acquisition_date BETWEEN %s AND %s
        ORDER BY acquisition_date;
    """, (west, south, east, north, start_date, end_date))

    results = cur.fetchall()
    cur.close()
    return results
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import glob
import traceback
import datetime

def run_pipeline(config):
    phase_label = 'Google Drive' if config['phase'] == 1 else 'AWS S3'
    print(f"{'='*65}\n  PIPELINE | Phase {config['phase']}: {phase_label} -> COG -> S3 + PostGIS\n{'='*65}")

    summary = {'total_found': 0, 'processed': 0, 'skipped': 0, 'failed': 0,
               'total_size_mb': 0, 'start_time': datetime.datetime.now()}

    # --- Connections ---
    s3_client = None
    if config.get('upload_to_s3') or config['phase'] == 2:
        s3_client = get_s3_client(config)
        if s3_client is None and config['phase'] == 2:
            print("[FATAL] Phase 2 requires S3. Aborting.")
            return summary

    conn = get_db_connection(config)
    if conn is None:
        print("[FATAL] Cannot connect to database. Aborting.")
        return summary

    setup_database(conn)

    # --- Discover files ---
    if config['phase'] == 1:
        source_dir = config['drive_source_dir']
        if not os.path.exists(source_dir):
            print(f"[ERROR] Drive source not found: {source_dir}")
            conn.close()
            return summary
        input_files = sorted(glob.glob(os.path.join(source_dir, '*.tif')) +
                             glob.glob(os.path.join(source_dir, '*.TIF')))
        for f in input_files:
            print(f"  {os.path.basename(f)} ({os.path.getsize(f)/1e6:.1f} MB)")
    else:
        input_files = list_s3_raw_files(config, s3_client)

    summary['total_found'] = len(input_files)
    print(f"  Total files to process: {len(input_files)}")

    if not input_files:
        conn.close()
        return summary

    # --- Process each file ---
    for idx, input_item in enumerate(input_files, 1):
        print(f"\n[{idx}/{len(input_files)}] {os.path.basename(str(input_item))}")
        local_raw_path = local_cog_path = None
        cleanup_raw = cleanup_cog = False

        try:
            # Get local file
            if config['phase'] == 1:
                local_raw_path = input_item
            else:
                local_raw_path = download_from_s3(input_item, config['local_work_dir'], config, s3_client)
                cleanup_raw = True

            if not local_raw_path or not os.path.exists(local_raw_path):
                summary['failed'] += 1
                continue

            # Parse filename
            tile_meta = parse_hls_filename(local_raw_path)
            tile_id   = tile_meta['tile_id']
            print(f"  {tile_id} | {tile_meta['acquisition_date']} | {tile_meta['product']}")

            # Skip if already indexed
            if config.get('skip_existing'):
                cur = conn.cursor()
                cur.execute(
                    "SELECT acquisition_date FROM vegetation_metadata WHERE tile_id = %s",
                    (tile_id,)
                )
                existing = cur.fetchone()
                if existing:
                    existing_date = existing[0]
                    incoming_date = tile_meta.get('acquisition_date')
                    if existing_date == incoming_date:
                        print(f"  [SKIP] Already indexed with matching date")
                        summary['skipped'] += 1
                        cur.close()
                        continue
                    print(
                        f"  [REPAIR] Date mismatch for {tile_id}: "
                        f"db={existing_date}, parsed={incoming_date}. Reprocessing."
                    )
                cur.close()

            # Convert to COG if needed
            cog_info = validate_cog(local_raw_path)
            if cog_info['is_valid']:
                local_cog_path = local_raw_path
            else:
                print(f"  Issues: {'; '.join(cog_info['issues'])}")
                cog_filename   = os.path.basename(local_raw_path).replace('.tif', '.cog.tif')
                local_cog_path = os.path.join(config['local_work_dir'], cog_filename)
                cleanup_cog    = True
                conv_result    = convert_to_cog(local_raw_path, local_cog_path, config)
                if not conv_result['success']:
                    print(f"  [ERROR] {conv_result['error']}")
                    summary['failed'] += 1
                    continue
                benchmark_cog_vs_original(local_raw_path, local_cog_path, n_trials=2)

            # Extract metadata
            raster_meta = extract_raster_metadata(local_cog_path)
            bbox = raster_meta['bbox_wgs84']
            print(f"  BBox: W={bbox['west']:.4f} S={bbox['south']:.4f} "
                  f"E={bbox['east']:.4f} N={bbox['north']:.4f} | "
                  f"{raster_meta['width_px']}x{raster_meta['height_px']}px | "
                  f"{raster_meta['resolution_m']}m")

            # Upload to S3
            file_url = local_cog_path
            if config.get('upload_to_s3') and s3_client:
                file_url = upload_cog_to_s3(local_cog_path, config, s3_client, tile_meta) or local_cog_path

            # Index in PostGIS
            if insert_scene_metadata(conn, tile_meta, raster_meta, file_url,config):
                summary['processed']     += 1
                summary['total_size_mb'] += os.path.getsize(local_cog_path) / 1e6
                print(f"  [OK] {tile_id}")
            else:
                summary['failed'] += 1

        except Exception as e:
            print(f"  [ERROR] {e}")
            traceback.print_exc()
            summary['failed'] += 1
            if conn and not conn.closed:
                conn.rollback()

        finally:
            if cleanup_raw and local_raw_path and os.path.exists(local_raw_path):
                os.remove(local_raw_path)
            if cleanup_cog and local_cog_path and os.path.exists(local_cog_path):
                os.remove(local_cog_path)

    # --- Summary ---
    duration = (datetime.datetime.now() - summary['start_time']).total_seconds()
    print(f"\n{'='*65}\n  DONE in {duration:.1f}s | "
          f"Processed: {summary['processed']} | "
          f"Skipped: {summary['skipped']} | "
          f"Failed: {summary['failed']}\n{'='*65}")

    if conn and not conn.closed:
        cur = conn.cursor()
        cur.execute("SELECT COUNT(*), MIN(acquisition_date), MAX(acquisition_date) FROM vegetation_metadata")
        count, min_d, max_d = cur.fetchone()
        print(f"  DB: {count} scenes indexed | {min_d} to {max_d}")
        cur.close()
        conn.close()

    return summary
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
CONFIG = {
    # AWS
    'aws_access_key_id':     AWS_ACCESS_KEY_ID,
    'aws_secret_access_key': AWS_SECRET_ACCESS_KEY,
    'aws_region':            "us-west-1",
    's3_bucket':             S3_BUCKET_NAME,
    's3_cog_prefix':         'cog/',          # Where COGs are stored in S3
    's3_raw_prefix':         S3_RAW_PREFIX,   # Where raw tifs are in S3 (Phase 2)

    # Database
    'db_config':             DB_CONFIG,

    # Processing
    'phase':                 0,
    'local_work_dir':        LOCAL_WORK_DIR,
    'upload_to_s3':          True,            # Upload COGs to S3 after conversion
    'skip_existing':         True,            # Skip if tile_id already in DB

    # COG conversion parameters
    'cog_compress':          'LZW',           # Options: LZW, DEFLATE, ZSTD
    'cog_blocksize':         512,             # Tile size in pixels (512x512)
    'cog_overviews':         [2, 4, 8, 16],  # Overview levels for multi-res access

    # NDVI computation (optional, computed during metadata extraction)
    'compute_ndvi_preview':  True,            # Compute NDVI stats during ingestion
    'ndvi_sample_size':      1000,            # Pixels to sample for NDVI stats (fast)
}

print("Starting Vegetation Anomaly Detection Pipeline...")
print("This will:")
print("  1. Connect to AWS S3 and RDS PostgreSQL")
print("  2. Find all .tif files in your Google Drive source folder")
print("  3. Convert each file to COG format")
print("  4. Upload COGs to S3")
print("  5. Index metadata in PostGIS with spatial + temporal indexes")
print("")

# Run the complete pipeline
summary = run_pipeline(CONFIG)

print(f"\\nPipeline returned: {summary['processed']} scenes successfully indexed")
# Out:
# Starting Vegetation Anomaly Detection Pipeline...
# This will:
#   1. Connect to AWS S3 and RDS PostgreSQL
#   2. Find all .tif files in your Google Drive source folder
#   3. Convert each file to COG format
#   4. Upload COGs to S3
#   5. Index metadata in PostGIS with spatial + temporal indexes
#
# =================================================================
#   PIPELINE | Phase 2: AWS S3 -> COG -> S3 + PostGIS
# =================================================================
#   S3 connected: s3://vegetation-anomaly-cogs (region: us-west-1)
#   Database connected successfully!
#   PostgreSQL version: 17.6
#   PostGIS version: 3.5
#   Setting up PostGIS extensions...
#   Creating vegetation_metadata table...
#   Creating GIST spatial index (idx_vegetation_geom)...
#   Creating temporal index (idx_vegetation_date)...
#   Database schema initialized!
#   Indexes created: 6
#     - idx_vegetation_dataset
#     - idx_vegetation_date
#     - idx_vegetation_geom
#     - idx_vegetation_tile_date
#     - unique_tile_dataset
#     - vegetation_metadata_pkey
#   Found 593 raw TIF files in s3://vegetation-anomaly-cogs/50m_resolution/raw/
#   Total files to process: 593
#
# [1/593] veg_2015-08-09.tif
#   Downloading 1.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2015-08-09.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2015-08-09.tif
#   [WARN] Non-HLS filename: veg_2015-08-09.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2015-08-09 | 2015-08-09 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2015-08-09.tif
#   Done in 0.87s | 1.7 MB -> 4.1 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.9ms avg
#     COG:      23.7ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 4.1 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-08-09.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-08-09.cog.tif
#   [OK] veg_2015-08-09
#
# [2/593] veg_2015-12-02.tif
#   Downloading 0.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2015-12-02.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2015-12-02.tif
#   [WARN] Non-HLS filename: veg_2015-12-02.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2015-12-02 | 2015-12-02 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2015-12-02.tif
#   Done in 0.77s | 0.7 MB -> 1.7 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 14.8ms avg
#     COG:      27.8ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 1.7 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-12-02.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-12-02.cog.tif
#   [OK] veg_2015-12-02
#
# [3/593] veg_2015-12-12.tif
#   Downloading 3.0 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2015-12-12.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2015-12-12.tif
#   [WARN] Non-HLS filename: veg_2015-12-12.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2015-12-12 | 2015-12-12 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2015-12-12.tif
#   Done in 1.44s | 3.0 MB -> 6.9 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 14.6ms avg
#     COG:      31.9ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 6.9 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-12-12.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-12-12.cog.tif
#   [OK] veg_2015-12-12
#
# [4/593] veg_2015-12-27.tif
#   Downloading 13.1 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2015-12-27.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2015-12-27.tif
#   [WARN] Non-HLS filename: veg_2015-12-27.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2015-12-27 | 2015-12-27 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2015-12-27.tif
#   Done in 1.95s | 13.1 MB -> 31.2 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 17.6ms avg
#     COG:      64.9ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 31.2 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-12-27.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2015/veg_2015-12-27.cog.tif
#   [OK] veg_2015-12-27
#
# [5/593] veg_2016-01-01.tif
#   Downloading 3.4 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-01-01.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-01-01.tif
#   [WARN] Non-HLS filename: veg_2016-01-01.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-01-01 | 2016-01-01 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-01-01.tif
#   Done in 1.01s | 3.4 MB -> 7.9 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.1ms avg
#     COG:      25.6ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 7.9 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-01-01.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-01-01.cog.tif
#   [OK] veg_2016-01-01
#
# [6/593] veg_2016-01-26.tif
#   Downloading 7.6 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-01-26.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-01-26.tif
#   [WARN] Non-HLS filename: veg_2016-01-26.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-01-26 | 2016-01-26 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-01-26.tif
#   Done in 1.43s | 7.6 MB -> 18.3 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 15.5ms avg
#     COG:      52.3ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 18.3 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-01-26.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-01-26.cog.tif
#   [OK] veg_2016-01-26
#
# [7/593] veg_2016-01-31.tif
#   Downloading 3.0 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-01-31.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-01-31.tif
#   [WARN] Non-HLS filename: veg_2016-01-31.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-01-31 | 2016-01-31 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-01-31.tif
#   Done in 1.43s | 3.0 MB -> 7.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 13.0ms avg
#     COG:      30.5ms avg
#     Speedup:  0.4x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 7.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-01-31.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-01-31.cog.tif
#   [OK] veg_2016-01-31
#
# [8/593] veg_2016-02-05.tif
#   Downloading 1.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-02-05.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-02-05.tif
#   [WARN] Non-HLS filename: veg_2016-02-05.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-02-05 | 2016-02-05 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-02-05.tif
#   Done in 0.95s | 1.8 MB -> 4.2 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.1ms avg
#     COG:      22.1ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 4.2 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-02-05.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-02-05.cog.tif
#   [OK] veg_2016-02-05
#
# [9/593] veg_2016-02-15.tif
#   Downloading 8.3 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-02-15.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-02-15.tif
#   [WARN] Non-HLS filename: veg_2016-02-15.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-02-15 | 2016-02-15 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-02-15.tif
#   Done in 1.51s | 8.3 MB -> 20.3 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 16.4ms avg
#     COG:      51.2ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 20.3 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-02-15.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-02-15.cog.tif
#   [OK] veg_2016-02-15
#
# [10/593] veg_2016-02-25.tif
#   Downloading 0.9 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-02-25.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-02-25.tif
#   [WARN] Non-HLS filename: veg_2016-02-25.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-02-25 | 2016-02-25 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-02-25.tif
#   Done in 0.77s | 0.9 MB -> 2.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.7ms avg
#     COG:      21.1ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 2.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-02-25.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-02-25.cog.tif
#   [OK] veg_2016-02-25
#
# [11/593] veg_2016-04-05.tif
#   Downloading 12.5 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-04-05.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-04-05.tif
#   [WARN] Non-HLS filename: veg_2016-04-05.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-04-05 | 2016-04-05 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-04-05.tif
#   Done in 1.97s | 12.5 MB -> 30.2 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 16.6ms avg
#     COG:      63.0ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 30.2 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-04-05.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-04-05.cog.tif
#   [OK] veg_2016-04-05
#
# [12/593] veg_2016-04-10.tif
#   Downloading 3.1 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-04-10.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-04-10.tif
#   [WARN] Non-HLS filename: veg_2016-04-10.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-04-10 | 2016-04-10 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-04-10.tif
#   Done in 1.48s | 3.1 MB -> 7.5 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 13.4ms avg
#     COG:      29.8ms avg
#     Speedup:  0.4x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 7.5 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-04-10.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-04-10.cog.tif
#   [OK] veg_2016-04-10
#
# [13/593] veg_2016-04-30.tif
#   Downloading 5.6 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-04-30.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-04-30.tif
#   [WARN] Non-HLS filename: veg_2016-04-30.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-04-30 | 2016-04-30 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-04-30.tif
#   Done in 1.26s | 5.6 MB -> 13.4 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.9ms avg
#     COG:      23.9ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 13.4 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-04-30.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-04-30.cog.tif
#   [OK] veg_2016-04-30
#
# [14/593] veg_2016-05-30.tif
#   Downloading 3.0 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-05-30.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-05-30.tif
#   [WARN] Non-HLS filename: veg_2016-05-30.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-05-30 | 2016-05-30 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-05-30.tif
#   Done in 0.98s | 3.0 MB -> 7.3 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.2ms avg
#     COG:      24.1ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 7.3 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-05-30.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-05-30.cog.tif
#   [OK] veg_2016-05-30
#
# [15/593] veg_2016-06-04.tif
#   Downloading 12.6 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-06-04.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-06-04.tif
#   [WARN] Non-HLS filename: veg_2016-06-04.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-06-04 | 2016-06-04 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-06-04.tif
#   Done in 1.95s | 12.6 MB -> 30.3 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 16.2ms avg
#     COG:      61.2ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 30.3 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-06-04.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-06-04.cog.tif
#   [OK] veg_2016-06-04
#
# [16/593] veg_2016-06-14.tif
#   Downloading 8.1 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-06-14.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-06-14.tif
#   [WARN] Non-HLS filename: veg_2016-06-14.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-06-14 | 2016-06-14 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-06-14.tif
#   Done in 1.45s | 8.1 MB -> 19.6 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 15.6ms avg
#     COG:      48.2ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 19.6 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-06-14.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-06-14.cog.tif
#   [OK] veg_2016-06-14
#
# [17/593] veg_2016-06-24.tif
#   Downloading 12.3 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-06-24.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-06-24.tif
#   [WARN] Non-HLS filename: veg_2016-06-24.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-06-24 | 2016-06-24 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-06-24.tif
#   Done in 2.38s | 12.3 MB -> 29.8 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 16.0ms avg
#     COG:      55.4ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 29.8 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-06-24.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-06-24.cog.tif
#   [OK] veg_2016-06-24
#
# [18/593] veg_2016-07-04.tif
#   Downloading 7.5 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-07-04.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-07-04.tif
#   [WARN] Non-HLS filename: veg_2016-07-04.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-07-04 | 2016-07-04 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-07-04.tif
#   Done in 1.36s | 7.5 MB -> 18.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 15.2ms avg
#     COG:      50.7ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 18.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-04.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-04.cog.tif
#   [OK] veg_2016-07-04
#
# [19/593] veg_2016-07-09.tif
#   Downloading 2.9 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-07-09.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-07-09.tif
#   [WARN] Non-HLS filename: veg_2016-07-09.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-07-09 | 2016-07-09 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-07-09.tif
#   Done in 0.98s | 2.9 MB -> 6.9 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.8ms avg
#     COG:      22.8ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 6.9 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-09.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-09.cog.tif
#   [OK] veg_2016-07-09
#
# [20/593] veg_2016-07-14.tif
#   Downloading 12.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-07-14.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-07-14.tif
#   [WARN] Non-HLS filename: veg_2016-07-14.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-07-14 | 2016-07-14 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-07-14.tif
#   Done in 1.95s | 12.7 MB -> 30.4 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 22.9ms avg
#     COG:      81.8ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 30.4 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-14.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-14.cog.tif
#   [OK] veg_2016-07-14
#
# [21/593] veg_2016-07-19.tif
#   Downloading 1.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-07-19.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-07-19.tif
#   [WARN] Non-HLS filename: veg_2016-07-19.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-07-19 | 2016-07-19 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-07-19.tif
#   Done in 0.84s | 1.8 MB -> 4.1 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.7ms avg
#     COG:      21.6ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 4.1 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-19.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-19.cog.tif
#   [OK] veg_2016-07-19
#
# [22/593] veg_2016-07-29.tif
#   Downloading 3.2 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-07-29.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-07-29.tif
#   [WARN] Non-HLS filename: veg_2016-07-29.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-07-29 | 2016-07-29 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-07-29.tif
#   Done in 0.98s | 3.2 MB -> 7.7 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.1ms avg
#     COG:      24.5ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 7.7 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-29.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-07-29.cog.tif
#   [OK] veg_2016-07-29
#
# [23/593] veg_2016-08-08.tif
#   Downloading 5.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-08-08.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-08-08.tif
#   [WARN] Non-HLS filename: veg_2016-08-08.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-08-08 | 2016-08-08 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-08-08.tif
#   Done in 1.29s | 5.7 MB -> 13.5 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 15.2ms avg
#     COG:      25.3ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 13.5 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-08.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-08.cog.tif
#   [OK] veg_2016-08-08
#
# [24/593] veg_2016-08-13.tif
#   Downloading 0.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-08-13.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-08-13.tif
#   [WARN] Non-HLS filename: veg_2016-08-13.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-08-13 | 2016-08-13 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-08-13.tif
#   Done in 0.78s | 0.8 MB -> 1.8 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.8ms avg
#     COG:      22.7ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 1.8 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-13.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-13.cog.tif
#   [OK] veg_2016-08-13
#
# [25/593] veg_2016-08-23.tif
#   Downloading 1.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-08-23.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-08-23.tif
#   [WARN] Non-HLS filename: veg_2016-08-23.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-08-23 | 2016-08-23 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-08-23.tif
#   Done in 0.87s | 1.7 MB -> 4.1 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.8ms avg
#     COG:      20.7ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 4.1 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-23.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-23.cog.tif
#   [OK] veg_2016-08-23
#
# [26/593] veg_2016-08-28.tif
#   Downloading 5.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-08-28.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-08-28.tif
#   [WARN] Non-HLS filename: veg_2016-08-28.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-08-28 | 2016-08-28 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-08-28.tif
#   Done in 1.85s | 5.7 MB -> 13.4 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 14.9ms avg
#     COG:      29.0ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 13.4 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-28.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-08-28.cog.tif
#   [OK] veg_2016-08-28
#
# [27/593] veg_2016-09-07.tif
#   Downloading 2.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-09-07.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-09-07.tif
#   [WARN] Non-HLS filename: veg_2016-09-07.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-09-07 | 2016-09-07 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-09-07.tif
#   Done in 0.95s | 2.8 MB -> 6.6 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.2ms avg
#     COG:      23.8ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 6.6 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-07.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-07.cog.tif
#   [OK] veg_2016-09-07
#
# [28/593] veg_2016-09-12.tif
#   Downloading 1.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-09-12.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-09-12.tif
#   [WARN] Non-HLS filename: veg_2016-09-12.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-09-12 | 2016-09-12 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-09-12.tif
#   Done in 0.88s | 1.7 MB -> 4.1 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.7ms avg
#     COG:      22.0ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 4.1 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-12.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-12.cog.tif
#   [OK] veg_2016-09-12
#
# [29/593] veg_2016-09-22.tif
#   Downloading 0.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-09-22.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-09-22.tif
#   [WARN] Non-HLS filename: veg_2016-09-22.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-09-22 | 2016-09-22 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-09-22.tif
#   Done in 0.77s | 0.8 MB -> 2.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.7ms avg
#     COG:      23.1ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 2.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-22.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-22.cog.tif
#   [OK] veg_2016-09-22
#
# [30/593] veg_2016-09-27.tif
#   Downloading 2.9 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-09-27.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-09-27.tif
#   [WARN] Non-HLS filename: veg_2016-09-27.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-09-27 | 2016-09-27 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-09-27.tif
#   Done in 0.96s | 2.9 MB -> 6.9 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.8ms avg
#     COG:      23.0ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 6.9 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-27.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-09-27.cog.tif
#   [OK] veg_2016-09-27
#
# [31/593] veg_2016-10-02.tif
#   Downloading 1.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-10-02.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-10-02.tif
#   [WARN] Non-HLS filename: veg_2016-10-02.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-10-02 | 2016-10-02 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-10-02.tif
#   Done in 0.85s | 1.7 MB -> 4.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.7ms avg
#     COG:      21.3ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 4.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-02.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-02.cog.tif
#   [OK] veg_2016-10-02
#
# [32/593] veg_2016-10-07.tif
#   Downloading 5.3 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-10-07.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-10-07.tif
#   [WARN] Non-HLS filename: veg_2016-10-07.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-10-07 | 2016-10-07 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-10-07.tif
#   Done in 1.2s | 5.3 MB -> 12.8 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.9ms avg
#     COG:      24.7ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 12.8 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-07.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-07.cog.tif
#   [OK] veg_2016-10-07
#
# [33/593] veg_2016-10-17.tif
#   Downloading 0.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-10-17.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-10-17.tif
#   [WARN] Non-HLS filename: veg_2016-10-17.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-10-17 | 2016-10-17 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-10-17.tif
#   Done in 1.09s | 0.8 MB -> 1.8 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 13.3ms avg
#     COG:      26.6ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 1.8 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-17.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-17.cog.tif
#   [OK] veg_2016-10-17
#
# [34/593] veg_2016-10-27.tif
#   Downloading 5.5 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-10-27.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-10-27.tif
#   [WARN] Non-HLS filename: veg_2016-10-27.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-10-27 | 2016-10-27 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-10-27.tif
#   Done in 1.24s | 5.5 MB -> 13.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 13.9ms avg
#     COG:      29.7ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 13.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-27.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-10-27.cog.tif
#   [OK] veg_2016-10-27
#
# [35/593] veg_2016-11-01.tif
#   Downloading 7.2 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-11-01.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-11-01.tif
#   [WARN] Non-HLS filename: veg_2016-11-01.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-11-01 | 2016-11-01 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-11-01.tif
#   Done in 1.41s | 7.2 MB -> 17.5 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 14.7ms avg
#     COG:      47.9ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 17.5 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-01.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-01.cog.tif
#   [OK] veg_2016-11-01
#
# [36/593] veg_2016-11-06.tif
#   Downloading 2.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-11-06.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-11-06.tif
#   [WARN] Non-HLS filename: veg_2016-11-06.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-11-06 | 2016-11-06 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-11-06.tif
#   Done in 0.95s | 2.8 MB -> 6.8 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.0ms avg
#     COG:      25.3ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 6.8 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-06.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-06.cog.tif
#   [OK] veg_2016-11-06
#
# [37/593] veg_2016-11-11.tif
#   Downloading 1.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-11-11.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-11-11.tif
#   [WARN] Non-HLS filename: veg_2016-11-11.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-11-11 | 2016-11-11 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-11-11.tif
#   Done in 0.84s | 1.7 MB -> 4.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.9ms avg
#     COG:      22.1ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 4.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-11.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-11.cog.tif
#   [OK] veg_2016-11-11
#
# [38/593] veg_2016-11-21.tif
#   Downloading 12.2 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-11-21.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-11-21.tif
#   [WARN] Non-HLS filename: veg_2016-11-21.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-11-21 | 2016-11-21 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-11-21.tif
#   Done in 2.38s | 12.2 MB -> 29.7 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 16.2ms avg
#     COG:      57.5ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 29.7 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-21.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-21.cog.tif
#   [OK] veg_2016-11-21
#
# [39/593] veg_2016-11-26.tif
#   Downloading 5.6 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-11-26.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-11-26.tif
#   [WARN] Non-HLS filename: veg_2016-11-26.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-11-26 | 2016-11-26 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-11-26.tif
#   Done in 1.27s | 5.6 MB -> 13.4 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 12.2ms avg
#     COG:      24.4ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 13.4 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-26.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-11-26.cog.tif
#   [OK] veg_2016-11-26
#
# [40/593] veg_2016-12-11.tif
#   Downloading 0.9 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-12-11.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-12-11.tif
#   [WARN] Non-HLS filename: veg_2016-12-11.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-12-11 | 2016-12-11 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-12-11.tif
#   Done in 1.1s | 0.9 MB -> 2.0 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.6ms avg
#     COG:      21.5ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 2.0 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-12-11.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-12-11.cog.tif
#   [OK] veg_2016-12-11
#
# [41/593] veg_2016-12-21.tif
#   Downloading 12.7 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-12-21.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-12-21.tif
#   [WARN] Non-HLS filename: veg_2016-12-21.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-12-21 | 2016-12-21 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-12-21.tif
#   Done in 1.92s | 12.7 MB -> 30.4 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 17.3ms avg
#     COG:      60.7ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 30.4 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-12-21.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-12-21.cog.tif
#   [OK] veg_2016-12-21
#
# [42/593] veg_2016-12-31.tif
#   Downloading 1.6 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2016-12-31.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2016-12-31.tif
#   [WARN] Non-HLS filename: veg_2016-12-31.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2016-12-31 | 2016-12-31 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2016-12-31.tif
#   Done in 1.22s | 1.6 MB -> 3.9 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 13.4ms avg
#     COG:      26.5ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 3.9 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-12-31.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2016/veg_2016-12-31.cog.tif
#   [OK] veg_2016-12-31
#
# [43/593] veg_2017-01-15.tif
#   Downloading 5.4 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2017-01-15.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2017-01-15.tif
#   [WARN] Non-HLS filename: veg_2017-01-15.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2017-01-15 | 2017-01-15 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2017-01-15.tif
#   Done in 1.2s | 5.4 MB -> 12.7 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.8ms avg
#     COG:      23.2ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 12.7 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2017/veg_2017-01-15.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2017/veg_2017-01-15.cog.tif
#   [OK] veg_2017-01-15
#
# [44/593] veg_2017-01-25.tif
#   Downloading 5.1 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2017-01-25.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2017-01-25.tif
#   [WARN] Non-HLS filename: veg_2017-01-25.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2017-01-25 | 2017-01-25 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2017-01-25.tif
#   Done in 1.18s | 5.1 MB -> 12.3 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.8ms avg
#     COG:      22.2ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 12.3 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/
MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2017-04-30.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2017-04-30.tif
#   [WARN] Non-HLS filename: veg_2017-04-30.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2017-04-30 | 2017-04-30 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2017-04-30.tif
#   Done in 1.19s | 5.3 MB -> 12.5 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 11.8ms avg
#     COG:      25.1ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 12.5 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2017/veg_2017-04-30.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2017/veg_2017-04-30.cog.tif
#   [OK] veg_2017-04-30
#
# [53/593] veg_2017-05-10.tif
#   Downloading 12.8 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2017-05-10.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2017-05-10.tif
#   [WARN] Non-HLS filename: veg_2017-05-10.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2017-05-10 | 2017-05-10 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2017-05-10.tif
#   Done in 2.46s | 12.8 MB -> 30.7 MB (0.4x compression)
#   Benchmark Results (2 trials):
#     Original: 16.2ms avg
#     COG:      63.2ms avg
#     Speedup:  0.3x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox: W=-105.7003 S=39.7999 E=-104.8997 N=40.3011 | 1714x1073px | 0.00046712394774215115m
#   Uploading 30.7 MB -> s3://vegetation-anomaly-cogs/50m_resolution/cog/2017/veg_2017-05-10.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/50m_resolution/cog/2017/veg_2017-05-10.cog.tif
#   [OK] veg_2017-05-10
#
# [54/593] veg_2017-05-20.tif
#   Downloading 5.4 MB from s3://vegetation-anomaly-cogs/50m_resolution/raw/new_raw/veg_2017-05-20.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2017-05-20.tif
#   [WARN] Non-HLS filename: veg_2017-05-20.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2017-05-20 | 2017-05-20 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2017-05-20.tif

# %%
print("=" * 65)
print("  SPATIAL QUERY VERIFICATION")
print("=" * 65)

# Reconnect for verification
conn_verify = get_db_connection(config=CONFIG)
if conn_verify:

    # --- Query 1: Show all indexed scenes ---
    # cur = conn_verify.cursor()
    # cur.execute("""
    #     SELECT
    #         tile_id,
    #         acquisition_date,
    #         ROUND(resolution_m::numeric, 1) AS res_m,
    #         ROUND(ndvi_mean::numeric, 3) AS ndvi,
    #         compression,
    #         has_overviews,
    #         LEFT(file_url, 60) AS file_url_preview,
    #         ST_AsText(ST_Envelope(geom)) AS bbox_wkt
    #     FROM vegetation_metadata
    #     ORDER BY acquisition_date;
    # """)
    # rows = cur.fetchall()
    # cur.close()

    # print(f"\\n[QUERY 1] All indexed scenes ({len(rows)} total):")
    # print(f"  {'tile_id':<30} {'date':<12} {'res':<6} {'ndvi':<7} {'compress':<10} {'ovr':<5}")
    # print(f"  {'-'*30} {'-'*12} {'-'*6} {'-'*7} {'-'*10} {'-'*5}")
    # for r in rows:
    #     ndvi_str = f"{r[3]:.3f}" if r[3] is not None else "N/A  "
    #     print(f"  {str(r[0]):<30} {str(r[1]):<12} {str(r[2]):<6} {ndvi_str:<7} {str(r[4]):<10} {str(r[5]):<5}")

    # --- Query 2: Spatiotemporal range query (Boulder County) ---
    # Boulder County, Colorado approximate bounds:
    # West: -105.7, South: 39.9, East: -105.0, North: 40.3
    boulder_bounds = (-105.7, 39.9, -105.0, 40.3)
    start_date = datetime.date(2015, 1, 1)
    end_date   = datetime.date(2025, 12, 31)

    print(f"\\n[QUERY 2] Spatiotemporal query - Boulder County, CO (2015-2025):")
    print(f"  Bounds: W={boulder_bounds[0]}, S={boulder_bounds[1]}, "
          f"E={boulder_bounds[2]}, N={boulder_bounds[3]}")

    results = run_spatiotemporal_query(
        conn_verify,
        *boulder_bounds,
        start_date, end_date
    )

    print(f"  Scenes overlapping Boulder County in range: {len(results)}")
    if results:
        print(f"  These scene URLs will be passed to PySpark for NDVI computation:")
        for r in results[:5]:
            url = str(r[2])[:70] + ('...' if len(str(r[2])) > 70 else '')
            print(f"    {r[0]} | {r[1]} | NDVI={r[3]} | {url}")

    # --- Query 3: EXPLAIN ANALYZE - verify GIST index is used ---
    print(f"\\n[QUERY 3] EXPLAIN ANALYZE - Verify GIST index usage:")
    cur = conn_verify.cursor()
    cur.execute("""
        EXPLAIN (ANALYZE, FORMAT TEXT)
        SELECT tile_id, file_url FROM vegetation_metadata
        WHERE ST_Intersects(geom, ST_MakeEnvelope(-105.7, 39.9, -105.0, 40.3, 4326));
    """)
    plan = cur.fetchall()
    cur.close()
    print("  Query Plan:")
    for line in plan[:10]:
        print(f"    {line[0]}")
    print("  (Look for 'Index Scan using idx_vegetation_geom' = GIST index is being used!)")

    # --- Query 4: Count scenes by year ---
    cur = conn_verify.cursor()
    cur.execute("""
        SELECT
            EXTRACT(YEAR FROM acquisition_date)::int AS year,
            COUNT(*) AS scene_count,
            ROUND(AVG(ndvi_mean)::numeric, 3) AS avg_ndvi,
            MIN(acquisition_date) AS first_date,
            MAX(acquisition_date) AS last_date
        FROM vegetation_metadata
        GROUP BY year
        ORDER BY year;
    """)
    yearly = cur.fetchall()
    cur.close()

    if yearly:
        print(f"\\n[QUERY 4] Scenes indexed by year:")
        print(f"  {'Year':<6} {'Scenes':<8} {'Avg NDVI':<10} {'First':<12} {'Last':<12}")
        print(f"  {'-'*6} {'-'*8} {'-'*10} {'-'*12} {'-'*12}")
        for row in yearly:
            ndvi = f"{row[2]:.3f}" if row[2] else "N/A"
            print(f"  {row[0]:<6} {row[1]:<8} {ndvi:<10} {str(row[3]):<12} {str(row[4]):<12}")

    conn_verify.close()
    print("\\nVerification complete. The spatiotemporal index is operational!")
    print("Next step: Use these scene URLs in PySpark for NDVI/NDMI computation (Section 5).")
# Out:
# =================================================================
#   SPATIAL QUERY VERIFICATION
# =================================================================
#   Database connected successfully!
#   PostgreSQL version: 17.6
#   PostGIS version: 3.5
# \n[QUERY 2] Spatiotemporal query - Boulder County, CO (2015-2025):
#   Bounds: W=-105.7, S=39.9, E=-105.0, N=40.3
#   Scenes overlapping Boulder County in range: 366
#   These scene URLs will be passed to PySpark for NDVI computation:
#     veg_2015-08-09 | 2015-08-09 | NDVI=None | s3://vegetation-anomaly-cogs/cog/2015/veg_2015-08-09.cog.tif
#     veg_2015-12-06 | 2015-12-06 | NDVI=None | s3://vegetation-anomaly-cogs/cog/2015/veg_2015-12-06.cog.tif
#     veg_2015-12-13 | 2015-12-13 | NDVI=None | s3://vegetation-anomaly-cogs/cog/2015/veg_2015-12-13.cog.tif
#     veg_2015-12-27 | 2015-12-27 | NDVI=None | s3://vegetation-anomaly-cogs/cog/2015/veg_2015-12-27.cog.tif
#     veg_2016-01-03 | 2016-01-03 | NDVI=None | s3://vegetation-anomaly-cogs/cog/2016/veg_2016-01-03.cog.tif
# \n[QUERY 3] EXPLAIN ANALYZE - Verify GIST index usage:
#   Query Plan:
#     Bitmap Heap Scan on vegetation_metadata  (cost=14.08..3157.58 rows=250 width=76) (actual time=0.066..0.538 rows=366 loops=1)
#       Filter: st_intersects(geom, '0103000020E61000000100000005000000CDCCCCCCCC6C5AC03333333333F34340CDCCCCCCCC6C5AC066666666662644400000000000405AC066666666662644400000000000405AC03333333333F34340CDCCCCCCCC6C5AC03333333333F34340'::geometry)
#       Heap Blocks: exact=16
#       ->  Bitmap Index Scan on idx_vegetation_geom  (cost=0.00..14.02 rows=250 width=0) (actual time=0.033..0.034 rows=370 loops=1)
#             Index Cond: (geom && '0103000020E61000000100000005000000CDCCCCCCCC6C5AC03333333333F34340CDCCCCCCCC6C5AC066666666662644400000000000405AC066666666662644400000000000405AC03333333333F34340CDCCCCCCCC6C5AC03333333333F34340'::geometry)
#     Planning Time: 0.261 ms
#     Execution Time: 0.576 ms
#   (Look for 'Index Scan using idx_vegetation_geom' = GIST index is being used!)
# \n[QUERY 4] Scenes indexed by year:
#   Year   Scenes   Avg NDVI   First        Last
#   ------ -------- ---------- ------------ ------------
#   2015   4        N/A        2015-08-09   2015-12-27
#   2016   34       N/A        2016-01-03   2016-12-18
#   2017   43       N/A        2017-01-01   2017-12-31
#   2018   48       N/A        2018-01-07   2018-12-30
#   2019   44       N/A        2019-01-06   2019-12-29
#   2020   45       N/A        2020-01-05   2020-12-20
#   2021   46       N/A        2021-01-03   2021-12-26
#   2022   46       N/A        2022-01-09   2022-12-26
#   2023   48       N/A        2023-01-23   2023-12-25
#   2024   8        N/A        2024-01-01   2024-02-26
# \nVerification complete. The spatiotemporal index is operational!
# Next step: Use these scene URLs in PySpark for NDVI/NDMI computation (Section 5).

# %%
# !pip install earthengine-api geemap boto3 python-dateutil
# Out:
# Requirement already satisfied: earthengine-api in /usr/local/lib/python3.12/dist-packages (1.5.24)
# Requirement already satisfied: geemap in /usr/local/lib/python3.12/dist-packages (0.35.3)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (1.42.68)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (2.9.0.post0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (3.9.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (2.192.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (2.47.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (0.3.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (0.31.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (2.32.4)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from geemap) (0.12.45)
# Requirement already satisfied: colour in /usr/local/lib/python3.12/dist-packages (from geemap) (0.1.5)
# Requirement already satisfied: eerepr>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from geemap) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from geemap) (0.20.0)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.12/dist-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from geemap) (2.0.4)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in /usr/local/lib/python3.12/dist-packages (from geemap) (0.20.0)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from geemap) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from geemap) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from geemap) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from geemap) (5.24.1)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from geemap) (1.11.0)
# Requirement already satisfied: pyshp>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from geemap) (3.0.3)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from geemap) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from geemap) (0.11.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.68 in /usr/local/lib/python3.12/dist-packages (from boto3) (1.42.68)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil) (1.17.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.68->boto3) (2.5.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium>=0.17.0->geemap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium>=0.17.0->geemap) (2025.11.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.3.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from ipyfilechooser>=0.6.0->geemap) (7.7.1)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet>=0.19.2->geemap) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet>=0.19.2->geemap) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from bqplot->geemap) (5.7.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->geemap) (2025.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geocoder->geemap) (8.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.12/dist-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap) (11.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->geemap) (9.1.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.27.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ratelim->geocoder->geemap) (4.4.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.9.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.4.0)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.7 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2

# %%
import ee
import subprocess

# Clear cached credentials
subprocess.run(['rm', '-rf', '/root/.config/earthengine'], capture_output=True)

# Force fresh authentication
ee.Authenticate(force=True)

# %%
import ee
ee.Initialize(project="vaulted-dolphin-474319-i7")
print("GEE ready!")
# Out:
# GEE ready!

# %%
import boto3
from google.colab import userdata

s3 = boto3.client(
    "s3",
    aws_access_key_id=userdata.get('AWS_ACCESS_KEY_ID'),
    aws_secret_access_key=userdata.get('AWS_SECRET_ACCESS_KEY'),
    region_name="us-west-1"
)

# Verify connection
response = s3.list_objects_v2(Bucket="vegetation-anomaly-cogs", MaxKeys=5)
print("S3 connected successfully")
print(f"Bucket: vegetation-anomaly-cogs")
print(f"Existing objects: {response.get('KeyCount', 0)}")
# Out:
# S3 connected successfully
# Bucket: vegetation-anomaly-cogs
# Existing objects: 5

# %%
import datetime, os, math, geemap
import boto3
import rasterio
from rasterio.merge import merge
from dateutil.relativedelta import relativedelta
from google.colab import userdata

# --- Config ---
BUCKET           = "vegetation-anomaly-cogs"
S3_PREFIX        = "20m_resolution/raw/"
SCALE            = 20
IMAGES_PER_MONTH = 10
MAX_CLOUD        = 40

TILES = [
    ee.Geometry.Rectangle([-105.75, 39.75, -105.55, 40.00]),
    ee.Geometry.Rectangle([-105.55, 39.75, -105.30, 40.00]),
    ee.Geometry.Rectangle([-105.30, 39.75, -105.05, 40.00]),
    ee.Geometry.Rectangle([-105.05, 39.75, -104.85, 40.00]),
    ee.Geometry.Rectangle([-105.75, 40.00, -105.55, 40.175]),
    ee.Geometry.Rectangle([-105.55, 40.00, -105.30, 40.175]),
    ee.Geometry.Rectangle([-105.30, 40.00, -105.05, 40.175]),
    ee.Geometry.Rectangle([-105.05, 40.00, -104.85, 40.175]),
    ee.Geometry.Rectangle([-105.75, 40.175, -105.55, 40.35]),
    ee.Geometry.Rectangle([-105.55, 40.175, -105.30, 40.35]),
    ee.Geometry.Rectangle([-105.30, 40.175, -105.05, 40.35]),
    ee.Geometry.Rectangle([-105.05, 40.175, -104.85, 40.35]),
]
FULL_REGION = ee.Geometry.Rectangle([-105.75, 39.75, -104.85, 40.35])

START = datetime.date(2019, 4, 1)
END   = datetime.date(2024, 10, 31)

s3 = boto3.client(
    "s3",
    aws_access_key_id=userdata.get('AWS_ACCESS_KEY_ID'),
    aws_secret_access_key=userdata.get('AWS_SECRET_ACCESS_KEY'),
    region_name="us-west-1"
)

os.makedirs("/content/data/tiles",  exist_ok=True)
os.makedirs("/content/data/merged", exist_ok=True)

# FIX 1: Added unmask(-9999) so masked pixels are nodata not zero
def mask_s2_clouds(image):
    qa         = image.select('QA60')
    cloud_mask = qa.bitwiseAnd(1 << 10).eq(0)
    return (image.divide(10000)
                 .updateMask(cloud_mask)
                 .unmask(-9999)              # ← FIXED
                 .copyProperties(image, ['system:time_start']))

dataset = (
    ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
    .filterBounds(FULL_REGION)
    .filter(ee.Filter.lt("CLOUDY_PIXEL_PERCENTAGE", MAX_CLOUD))
    .map(mask_s2_clouds)
    .select(["B4", "B8", "B11"])
)

def export_and_merge(image, date_str):
    tile_paths = []

    for i, tile in enumerate(TILES):
        tile_path = f"/content/data/tiles/tile_{i}_{date_str}.tif"
        try:
            geemap.ee_export_image(
                image.clip(tile),
                filename=tile_path,
                scale=SCALE,
                region=tile,
                file_per_band=False
            )
            # FIX 2: threshold raised to 50KB to filter truly empty tiles
            if os.path.exists(tile_path) and os.path.getsize(tile_path) > 50000:
                tile_paths.append(tile_path)
                print(f"      Tile {i+1}/{len(TILES)}: {os.path.getsize(tile_path)/1e6:.1f} MB ✓")
            else:
                print(f"      Tile {i+1}/{len(TILES)}: empty")
        except Exception as e:
            print(f"      Tile {i+1}/{len(TILES)} failed: {e}")

    if len(tile_paths) < 8:
        print(f"      [ERROR] Only {len(tile_paths)}/{len(TILES)} valid tiles — too cloudy")
        for p in tile_paths:
            if os.path.exists(p): os.remove(p)
        return None

    merged_path = f"/content/data/merged/veg_{date_str}.tif"
    try:
        sources           = [rasterio.open(p) for p in tile_paths]
        # FIX 3: pass nodata=-9999 so merge handles masked pixels correctly
        mosaic, transform = merge(sources, nodata=-9999)

        profile = sources[0].profile
        # FIX 4: added count and nodata to profile
        profile.update({
            'height':    mosaic.shape[1],
            'width':     mosaic.shape[2],
            'count':     mosaic.shape[0],
            'transform': transform,
            'compress':  'lzw',
            'nodata':    -9999              # ← FIXED
        })

        with rasterio.open(merged_path, 'w', **profile) as dst:
            dst.write(mosaic)

        for src in sources: src.close()

        size_mb = os.path.getsize(merged_path) / 1e6
        print(f"      Merged {len(tile_paths)}/{len(TILES)} tiles → {size_mb:.1f} MB")
        return merged_path

    except Exception as e:
        print(f"      [ERROR] Merge failed: {e}")
        return None
    finally:
        for p in tile_paths:
            if os.path.exists(p): os.remove(p)


total_uploaded = total_skipped = total_failed = 0
current        = START

while current <= END:
    month_end  = current + relativedelta(months=1) - datetime.timedelta(days=1)
    collection = dataset.filterDate(str(current), str(month_end))
    count      = collection.size().getInfo()

    if count == 0:
        print(f"  {current.strftime('%Y-%m')}: No clear scenes, skipping")
        current += relativedelta(months=1)
        continue

    image_list = collection.sort('system:time_start').toList(count)
    step       = max(1, math.floor(count / IMAGES_PER_MONTH))
    indices    = [min(i * step, count - 1) for i in range(min(count, IMAGES_PER_MONTH))]

    print(f"\n  {current.strftime('%Y-%m')}: {count} available, selecting {len(indices)}")

    month_uploaded = 0
    for idx in indices:
        image    = ee.Image(image_list.get(idx))
        date_str = datetime.datetime.fromtimestamp(
            image.get('system:time_start').getInfo() / 1000
        ).strftime('%Y-%m-%d')

        filename = f"veg_{date_str}.tif"
        s3_key   = f"{S3_PREFIX}{filename}"

        try:
            s3.head_object(Bucket=BUCKET, Key=s3_key)
            print(f"    [SKIP] {filename} already in S3")
            total_skipped += 1
            continue
        except:
            pass

        print(f"    Exporting {filename} in {len(TILES)} tiles...")
        merged_path = export_and_merge(image, date_str)

        if merged_path and os.path.exists(merged_path):
            size_mb = os.path.getsize(merged_path) / 1e6
            if size_mb < 10:
                print(f"    [SKIP] {filename} only {size_mb:.1f} MB — too cloudy, discarding")
                os.remove(merged_path)
                total_failed += 1
                continue
            try:
                s3.upload_file(
                    merged_path, BUCKET, s3_key,
                    ExtraArgs={
                        'ContentType': 'image/tiff',
                        'Metadata': {
                            'resolution': '20m',
                            'bands':      'B4-Red,B8-NIR,B11-SWIR',
                            'date':       date_str,
                            'source':     'Sentinel-2-SR-Harmonized',
                            'region':     'Boulder-County-CO'
                        }
                    }
                )
                print(f"    [OK] {filename} ({size_mb:.1f} MB) → s3://{BUCKET}/{s3_key}")
                total_uploaded += 1
                month_uploaded += 1
            except Exception as e:
                print(f"    [ERROR] S3 upload failed: {e}")
                total_failed += 1
            finally:
                if os.path.exists(merged_path):
                    os.remove(merged_path)
        else:
            print(f"    [ERROR] Export failed: {filename}")
            total_failed += 1

    print(f"  {current.strftime('%Y-%m')}: {month_uploaded} uploaded")
    current += relativedelta(months=1)

print(f"\n{'='*55}")
print(f"  Uploaded : {total_uploaded} | Skipped: {total_skipped} | Failed: {total_failed}")
print(f"  Location : s3://{BUCKET}/{S3_PREFIX}")
print(f"{'='*55}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   2021-11: 30 available, selecting 10
#     Exporting veg_2021-11-04.tif in 12 tiles...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/e50dc41afa3b208849db29ac95ff7cd6-03a0ee28e3f3ae817e228c3872cd1a8c:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_0_2021-11-04.tif
#       Tile 1/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/d123c208cd07ffa9a5ccd453ca99d775-2e645a26a69e8a7aee637b10c0e10e9d:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_1_2021-11-04.tif
#       Tile 2/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/33876405f60e4c856dee9750bcf665ef-c85eb19d740ab8287120068125deda03:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_2_2021-11-04.tif
#       Tile 3/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/2c8ca64fd36b4660212b655b476f8852-adfb872740095525d68dbe5adde492b0:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_3_2021-11-04.tif
#       Tile 4/12: 6.4 MB ✓
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/96a46b7d88f5461c8edb20b335f98372-764182260abd099476a6ea0ff74bc38d:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_4_2021-11-04.tif
#       Tile 5/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/dd7eb471610ded87a0b9e80c91fa1ef8-3af9d1e363972b17e4e00b5c3bdaf4db:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_5_2021-11-04.tif
#       Tile 6/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/b9c78181b067f85fce91f60b22c82835-8c053deaf7a3d6e7717fd1bdde42e752:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_6_2021-11-04.tif
#       Tile 7/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/659adc21717e95806dba5f6d458b1ad2-e17b6f4d6726a4a60914acc30c9fee14:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_7_2021-11-04.tif
#       Tile 8/12: 4.4 MB ✓
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/1176c01ce1c083155fa0fe2886e5bc4d-8931b42c1beda0f59e284b363bd44b96:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_8_2021-11-04.tif
#       Tile 9/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/d79db8231315b1b08e25403647a82452-292f00d458880b42776b9a774469d4e0:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_9_2021-11-04.tif
#       Tile 10/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/90d5ebbb3a7e155d4b11dfc40ac7850a-77c7edb2394149f71940087ac8d54067:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_10_2021-11-04.tif
#       Tile 11/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/60c0ad98c1f109e53d812bbbac189c4b-b6507ec70c22ff9ce64b771dd96025e2:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_7_2024-07-16.tif
#       Tile 8/12: 4.6 MB ✓
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/431096b9088cf03c553a3643ae23eabb-d2b35e6e7e49391a4c22221f05939443:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_8_2024-07-16.tif
#       Tile 9/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/05231eeb3d55ec3ced413e3e9e8d7fed-01b952197f9ecd8dee9b8e43457a0571:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_9_2024-07-16.tif
#       Tile 10/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/fd0e4c23df16947483515758f904910a-9c6b2f540c2d0df73bd3acd1e663a1a8:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_10_2024-07-16.tif
#       Tile 11/12: 1.1 MB ✓
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/f97a71653f3ae751b96fb760d59aedc0-23c6e5dced589b0148d85f38ace9ecb4:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_11_2024-07-16.tif
#       Tile 12/12: 2.1 MB ✓
#       [ERROR] Only 7/12 valid tiles — too cloudy
#     [ERROR] Export failed: veg_2024-07-16.tif
#     Exporting veg_2024-07-24.tif in 12 tiles...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/f13e6e07e8d2662860ba390b3c1339b2-fcd7ea5b74fec25ff6d246e1eebccd83:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_0_2024-07-24.tif
#       Tile 1/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/13bf6e2f8b2394307568c5b6e2c5e904-9d5adfc608105402818bdaf27b76fdf4:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_1_2024-07-24.tif
#       Tile 2/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/6a3d6ffa678659ac3abe16890818f160-a44c75d31f0495e8f7715b58ed43c178:getPixels
# Please wait ...
# Data downloaded to /content/data/tiles/tile_2_2024-07-24.tif
#       Tile 3/12: empty
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/vaulted-dolphin-474319-i7/thumbnails/31ee9013e11fdd7cdcb2d8229fa0f624-2c3af2ac49508137f8feb33e234b61e8:getPixels
# Please wait ...

# %%
CONFIG = {
    # AWS
    'aws_access_key_id':     AWS_ACCESS_KEY_ID,
    'aws_secret_access_key': AWS_SECRET_ACCESS_KEY,
    'aws_region':            "us-west-1",
    's3_bucket':             S3_BUCKET_NAME,
    's3_cog_prefix':         '20m_resolution/cog/',          # Where COGs are stored in S3
    's3_raw_prefix':         '20m_resolution/raw/',   # Where raw tifs are in S3 (Phase 2)

    # Database
    'db_config':             DB_CONFIG,

    # Processing
    'phase':                 0,
    'local_work_dir':        LOCAL_WORK_DIR,
    'upload_to_s3':          True,            # Upload COGs to S3 after conversion
    'skip_existing':         False,            # Skip if tile_id already in DB
    'dataset': '20m_sentinel2',

    # COG conversion parameters
    'cog_compress':          'LZW',           # Options: LZW, DEFLATE, ZSTD
    'cog_blocksize':         512,             # Tile size in pixels (512x512)
    'cog_overviews':         [2, 4, 8, 16],  # Overview levels for multi-res access

    # NDVI computation (optional, computed during metadata extraction)
    'compute_ndvi_preview':  True,            # Compute NDVI stats during ingestion
    'ndvi_sample_size':      1000,            # Pixels to sample for NDVI stats (fast)
}

print("Starting Vegetation Anomaly Detection Pipeline...")
print("This will:")
print("  1. Connect to AWS S3 and RDS PostgreSQL")
print("  2. Find all .tif files in your Google Drive source folder")
print("  3. Convert each file to COG format")
print("  4. Upload COGs to S3")
print("  5. Index metadata in PostGIS with spatial + temporal indexes")
print("")

# Run the complete pipeline
summary = run_pipeline(CONFIG)

print(f"\\nPipeline returned: {summary['processed']} scenes successfully indexed")
# Out:
# Starting Vegetation Anomaly Detection Pipeline...
# This will:
#   1. Connect to AWS S3 and RDS PostgreSQL
#   2. Find all .tif files in your Google Drive source folder
#   3. Convert each file to COG format
#   4. Upload COGs to S3
#   5. Index metadata in PostGIS with spatial + temporal indexes
#
# =================================================================
#   PIPELINE | Phase 0: AWS S3 -> COG -> S3 + PostGIS
# =================================================================
#   S3 connected: s3://vegetation-anomaly-cogs (region: us-west-1)
#   Database connected successfully!
#   PostgreSQL version: 17.6
#   PostGIS version: 3.5
#   Setting up PostGIS extensions...
#   Creating vegetation_metadata table...
#   Creating GIST spatial index (idx_vegetation_geom)...
#   Creating temporal index (idx_vegetation_date)...
#   Database schema initialized!
#   Indexes created: 6
#     - idx_vegetation_dataset
#     - idx_vegetation_date
#     - idx_vegetation_geom
#     - idx_vegetation_tile_date
#     - unique_tile_dataset
#     - vegetation_metadata_pkey
#   Found 104 raw TIF files in s3://vegetation-anomaly-cogs/20m_resolution/raw/
#   Total files to process: 104
#
# [1/104] veg_2019-04-07.tif
#   Downloading 131.4 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-04-07.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-04-07.tif
#   [WARN] Non-HLS filename: veg_2019-04-07.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-04-07 | 2019-04-07 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-04-07.tif
#   Done in 9.65s | 131.4 MB -> 178.9 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 32.4ms avg
#     COG:      63.6ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 178.9 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-07.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-07.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [2/104] veg_2019-04-14.tif
#   Downloading 51.8 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-04-14.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-04-14.tif
#   [WARN] Non-HLS filename: veg_2019-04-14.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-04-14 | 2019-04-14 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-04-14.tif
#   Done in 4.58s | 51.8 MB -> 70.8 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 6.2ms avg
#     COG:      10.7ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 70.8 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-14.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-14.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [3/104] veg_2019-04-19.tif
#   Downloading 53.6 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-04-19.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-04-19.tif
#   [WARN] Non-HLS filename: veg_2019-04-19.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-04-19 | 2019-04-19 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-04-19.tif
#   Done in 4.57s | 53.6 MB -> 73.1 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 8.7ms avg
#     COG:      15.4ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 73.1 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-19.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-19.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [4/104] veg_2019-04-27.tif
#   Downloading 114.8 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-04-27.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-04-27.tif
#   [WARN] Non-HLS filename: veg_2019-04-27.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-04-27 | 2019-04-27 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-04-27.tif
#   Done in 8.48s | 114.8 MB -> 157.1 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 29.5ms avg
#     COG:      54.4ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 157.1 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-27.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-04-27.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [5/104] veg_2019-05-02.tif
#   Downloading 125.5 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-05-02.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-05-02.tif
#   [WARN] Non-HLS filename: veg_2019-05-02.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-05-02 | 2019-05-02 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-05-02.tif
#   Done in 9.11s | 125.5 MB -> 171.5 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 32.9ms avg
#     COG:      56.1ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 171.5 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-05-02.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-05-02.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [6/104] veg_2019-05-04.tif
#   Downloading 53.3 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-05-04.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-05-04.tif
#   [WARN] Non-HLS filename: veg_2019-05-04.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-05-04 | 2019-05-04 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-05-04.tif
#   Done in 4.58s | 53.3 MB -> 72.9 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 6.3ms avg
#     COG:      10.9ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 72.9 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-05-04.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-05-04.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [7/104] veg_2019-05-12.tif
#   Downloading 129.2 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-05-12.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-05-12.tif
#   [WARN] Non-HLS filename: veg_2019-05-12.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-05-12 | 2019-05-12 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-05-12.tif
#   Done in 9.37s | 129.2 MB -> 176.4 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 34.6ms avg
#     COG:      65.0ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 176.4 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-05-12.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-05-12.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [8/104] veg_2019-06-06.tif
#   Downloading 112.5 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-06-06.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-06-06.tif
#   [WARN] Non-HLS filename: veg_2019-06-06.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-06-06 | 2019-06-06 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-06-06.tif
#   Done in 7.83s | 112.5 MB -> 153.9 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 22.0ms avg
#     COG:      53.7ms avg
#     Speedup:  0.4x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 153.9 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-06.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-06.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [9/104] veg_2019-06-08.tif
#   Downloading 53.5 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-06-08.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-06-08.tif
#   [WARN] Non-HLS filename: veg_2019-06-08.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-06-08 | 2019-06-08 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-06-08.tif
#   Done in 4.52s | 53.5 MB -> 72.9 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 6.1ms avg
#     COG:      14.8ms avg
#     Speedup:  0.4x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 72.9 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-08.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-08.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [10/104] veg_2019-06-11.tif
#   Downloading 106.8 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-06-11.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-06-11.tif
#   [WARN] Non-HLS filename: veg_2019-06-11.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-06-11 | 2019-06-11 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-06-11.tif
#   Done in 8.17s | 106.8 MB -> 146.2 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 22.9ms avg
#     COG:      54.9ms avg
#     Speedup:  0.4x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 146.2 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-11.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-11.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [11/104] veg_2019-06-13.tif
#   Downloading 52.0 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-06-13.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-06-13.tif
#   [WARN] Non-HLS filename: veg_2019-06-13.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-06-13 | 2019-06-13 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-06-13.tif
#   Done in 5.32s | 52.0 MB -> 70.9 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 6.4ms avg
#     COG:      10.9ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 70.9 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-13.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-06-13.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [12/104] veg_2019-07-03.tif
#   Downloading 53.3 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-07-03.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-07-03.tif
#   [WARN] Non-HLS filename: veg_2019-07-03.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-07-03 | 2019-07-03 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-07-03.tif
#   Done in 5.08s | 53.3 MB -> 72.5 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 6.1ms avg
#     COG:      11.8ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 72.5 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-07-03.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-07-03.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [13/104] veg_2019-07-11.tif
#   Downloading 129.6 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-07-11.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-07-11.tif
#   [WARN] Non-HLS filename: veg_2019-07-11.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-07-11 | 2019-07-11 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-07-11.tif
#   Done in 8.76s | 129.6 MB -> 176.7 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 33.7ms avg
#     COG:      60.4ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 176.7 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-07-11.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-07-11.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [14/104] veg_2019-07-18.tif
#   Downloading 54.5 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-07-18.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-07-18.tif
#   [WARN] Non-HLS filename: veg_2019-07-18.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-07-18 | 2019-07-18 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-07-18.tif
#   Done in 4.99s | 54.5 MB -> 74.4 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 7.0ms avg
#     COG:      12.0ms avg
#     Speedup:  0.6x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 74.4 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-07-18.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2019/veg_2019-07-18.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [15/104] veg_2019-08-07.tif
#   Downloading 54.9 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2019-08-07.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2019-08-07.tif
#   [WARN] Non-HLS filename: veg_2019-08-07.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2019-08-07 | 2019-08-07 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2019-08-07.tif
#   Done in 5.49s | 54.9 MB -> 74.8 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original:
tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2025-11-08 | 2025-11-08 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2025-11-08.tif
#   Done in 9.21s | 129.2 MB -> 176.6 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 32.9ms avg
#     COG:      61.0ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 176.6 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2025/veg_2025-11-08.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2025/veg_2025-11-08.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# [104/104] veg_2025-12-16.tif
#   Downloading 128.3 MB from s3://vegetation-anomaly-cogs/20m_resolution/raw/veg_2025-12-16.tif
#   Downloaded -> /tmp/vegetation_pipeline/veg_2025-12-16.tif
#   [WARN] Non-HLS filename: veg_2025-12-16.tif. Attempting 'veg_YYYY-MM-DD' format.
#   veg_2025-12-16 | 2025-12-16 | CUSTOM_VEG
#   Issues: No overviews (partial zoom reads will be slow)
#   Converting to COG: veg_2025-12-16.tif
#   Done in 9.13s | 128.3 MB -> 175.2 MB (0.7x compression)
#   Benchmark Results (2 trials):
#     Original: 33.5ms avg
#     COG:      64.6ms avg
#     Speedup:  0.5x faster with COG
#   (On S3, this speedup is typically 10-50x for partial reads)
#   BBox WGS84: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524
#   BBox: W=-105.7501 S=39.7475 E=-104.8486 N=40.3524 | 3856x3344px | 20.0m
#   Uploading 175.2 MB -> s3://vegetation-anomaly-cogs/20m_resolution/cog/2025/veg_2025-12-16.cog.tif
#   Upload complete: s3://vegetation-anomaly-cogs/20m_resolution/cog/2025/veg_2025-12-16.cog.tif
#   [ERROR] Insert failed: not all arguments converted during string formatting
#
# =================================================================
#   DONE in 2007.4s | Processed: 0 | Skipped: 0 | Failed: 104
# =================================================================
#   DB: 618 scenes indexed | 2015-08-09 to 2026-03-06
# \nPipeline returned: 0 scenes successfully indexed

# %%
CONFIG = {
    # AWS
    'aws_access_key_id':     AWS_ACCESS_KEY_ID,
    'aws_secret_access_key': AWS_SECRET_ACCESS_KEY,
    'aws_region':            "us-west-1",
    's3_bucket':             S3_BUCKET_NAME,
    's3_cog_prefix':         'cog_30m/',          # Where COGs are stored in S3
    's3_raw_prefix':         'raw_30m_dataset/',   # Where raw tifs are in S3 (Phase 2)

    # Database
    'db_config':             DB_CONFIG,

    # Processing
    'phase':                 0,
    'local_work_dir':        LOCAL_WORK_DIR,
    'upload_to_s3':          True,            # Upload COGs to S3 after conversion
    'skip_existing':         False,            # Skip if tile_id already in DB
    'dataset': '30m_sentinel2',

    # COG conversion parameters
    'cog_compress':          'LZW',           # Options: LZW, DEFLATE, ZSTD
    'cog_blocksize':         512,             # Tile size in pixels (512x512)
    'cog_overviews':         [2, 4, 8, 16],  # Overview levels for multi-res access

    # NDVI computation (optional, computed during metadata extraction)
    'compute_ndvi_preview':  True,            # Compute NDVI stats during ingestion
    'ndvi_sample_size':      1000,            # Pixels to sample for NDVI stats (fast)
}

print("Starting Vegetation Anomaly Detection Pipeline...")
print("This will:")
print("  1. Connect to AWS S3 and RDS PostgreSQL")
print("  2. Find all .tif files in your Google Drive source folder")
print("  3. Convert each file to COG format")
print("  4. Upload COGs to S3")
print("  5. Index metadata in PostGIS with spatial + temporal indexes")
print("")

# Run the complete pipeline
summary = run_pipeline(CONFIG)

print(f"\\nPipeline returned: {summary['processed']} scenes successfully indexed")
